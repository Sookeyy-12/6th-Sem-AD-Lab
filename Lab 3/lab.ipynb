# %% [markdown]
# # Lab 3

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## 1. Load the Dataset
# Load the dataset from the provided file and display the first
# five rows. Write the code to load and preview the data.

# %%
df = pd.read_csv("../Data/Japan_life_expectancy.csv")
df.head()
# Out:
#   Prefecture  Life_expectancy  Physician  Junior_col  University  Public_Hosp  \
# 0      Aichi            84.65      224.4        13.6        23.7         13.7
# 1      Akita            83.79      242.6        11.3        11.9         34.0
# 2     Aomori            82.80      212.5        11.4        11.8         42.9
# 3      Chiba            84.48      205.8        14.7        24.9         16.1
# 4      Ehime            84.24      276.7        14.2        18.0         17.4
#
#    Pshic_hosp  Beds_psic  Nurses  Avg_hours  ...  Park  Forest  \
# 0         0.5      164.3   845.4      171.5  ...  17.2    42.1
# 1         1.7      404.6  1105.5      173.0  ...  10.6    70.3
# 2         1.4      348.7  1108.8      174.5  ...  11.8    63.6
# 3         0.5      195.8   749.1      173.5  ...   5.5    30.1
# 4         1.0      329.7  1277.5      178.0  ...   7.2    70.5
#
#    Income_per capita  Density_pop  Hospitals    Beds  Ambulances  Health_exp  \
# ...

# %% [markdown]
# ## 2. Display Basic Statistics
# Display the summary statistics (mean, median, standard
# deviation, etc.) for some numerical columns in the dataset.

# %%
df.describe()
# Out:
#        Life_expectancy   Physician  Junior_col  University  Public_Hosp  \
# count        47.000000   47.000000   47.000000   47.000000    47.000000
# mean         84.525745  261.438298   13.627660   18.621277    21.263830
# std           0.503133   40.948842    1.243191    4.459818    10.393548
# min          82.800000  177.800000   11.300000   11.800000     7.400000
# 25%          84.240000  230.400000   12.850000   15.750000    14.650000
# 50%          84.540000  257.900000   13.500000   18.100000    19.200000
# 75%          84.885000  290.950000   14.350000   20.600000    25.300000
# max          85.500000  338.400000   16.900000   31.600000    49.100000
#
#        Pshic_hosp   Beds_psic       Nurses   Avg_hours      Salary  ...  \
# count   47.000000   47.000000    47.000000   47.000000   47.000000  ...
# mean     1.114894  317.861702  1121.568085  173.914894  290.817021  ...
# std      0.557548  119.613115   244.333898    1.482943   24.657670  ...
# ...

# %% [markdown]
# ## 3. Identify Datatypes
# Identify and display the data types of each column in the
# dataset. What are the types of variables (categorical, numerical, etc.)?

# %%
print(df.dtypes)

categorical_columns = df.select_dtypes(include=['object']).columns
numerical_columns = df.select_dtypes(include=['float64']).columns

print("\nCategorical columns:", categorical_columns)
print("Numerical columns:", numerical_columns)
# Out:
# Prefecture            object
# Life_expectancy      float64
# Physician            float64
# Junior_col           float64
# University           float64
# Public_Hosp          float64
# Pshic_hosp           float64
# Beds_psic            float64
# Nurses               float64
# Avg_hours            float64
# Salary               float64
# Elementary_school    float64
# Sport_fac            float64
# Park                 float64
# Forest               float64
# Income_per capita    float64
# Density_pop          float64
# Hospitals            float64
# Beds                 float64
# Ambulances           float64
# Health_exp           float64
# Educ_exp             float64
# Welfare_exp          float64
# dtype: object
#
# Categorical columns: Index(['Prefecture'], dtype='object')
# Numerical columns: Index(['Life_expectancy', 'Physician', 'Junior_col', 'University',
#        'Public_Hosp', 'Pshic_hosp', 'Beds_psic', 'Nurses', 'Avg_hours',
# ...

# %% [markdown]
# ## 4. Check for missing values
# Write a script to check for missing values in each column and
# display the count of missing values.

# %%
df.isnull().sum()
# Out:
# Prefecture           0
# Life_expectancy      0
# Physician            0
# Junior_col           0
# University           0
# Public_Hosp          0
# Pshic_hosp           0
# Beds_psic            0
# Nurses               0
# Avg_hours            0
# Salary               0
# Elementary_school    0
# Sport_fac            0
# Park                 0
# Forest               0
# Income_per capita    0
# Density_pop          0
# Hospitals            0
# Beds                 0
# Ambulances           0
# Health_exp           0
# Educ_exp             0
# Welfare_exp          0
# dtype: int64

# %% [markdown]
# ## 5. Impute missing values
# Handle missing values by imputing them with the mean for
# numerical columns. Show the code and the updated dataset.

# %%
numerical_columns = df.select_dtypes(include=['float64']).columns

df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].mean())

# %% [markdown]
# ## 6. Generate a Correlation matrix
# Calculate the correlation matrix for all numerical attributes.
# Write the code to generate and display the matrix.

# %%
df.corr(numeric_only=True)
# Out:
#                    Life_expectancy  Physician  Junior_col  University  \
# Life_expectancy           1.000000   0.321545    0.569207    0.560164
# Physician                 0.321545   1.000000   -0.035781    0.085263
# Junior_col                0.569207  -0.035781    1.000000    0.493770
# University                0.560164   0.085263    0.493770    1.000000
# Public_Hosp              -0.091038  -0.222218   -0.236237   -0.424736
# Pshic_hosp               -0.240471   0.284066   -0.286641   -0.622081
# Beds_psic                -0.263259   0.412624   -0.315751   -0.649952
# Nurses                   -0.054996   0.634156   -0.168570   -0.552220
# Avg_hours                -0.111068   0.087101   -0.157295   -0.307384
# Salary                    0.406123   0.000284    0.346947    0.917426
# Elementary_school        -0.559066  -0.161057   -0.549658   -0.885628
# Sport_fac                -0.130514   0.011963   -0.067754   -0.701526
# ...

# %% [markdown]
# ## 7. Identify Highly Correlated Features
# Identify features that have a correlation value higher than 0.8
# or lower than -0.8. Write a script to highlight these pairs of attributes.

# %%
correlation_matrix = df.corr(numeric_only=True)

high_corr_pairs = []
""
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if correlation_matrix.iloc[i, j] > 0.8 or correlation_matrix.iloc[i, j] < -0.8:
            high_corr_pairs.append((correlation_matrix.columns[i], correlation_matrix.columns[j], correlation_matrix.iloc[i, j]))

high_corr_pairs
# Out:
# [('Beds_psic', 'Pshic_hosp', 0.888038840885009),
#  ('Nurses', 'Beds_psic', 0.901373283929733),
#  ('Salary', 'University', 0.9174256044858364),
#  ('Elementary_school', 'University', -0.8856281630304154),
#  ('Elementary_school', 'Salary', -0.8218751528102823),
#  ('Hospitals', 'Beds_psic', 0.8288319749287189),
#  ('Hospitals', 'Nurses', 0.895932834902771),
#  ('Beds', 'Beds_psic', 0.8261893419609975),
#  ('Beds', 'Nurses', 0.9274850206047406),
#  ('Beds', 'Hospitals', 0.9206958414801466)]
