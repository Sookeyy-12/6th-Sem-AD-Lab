# %% [markdown]
# # Lab 4:
#
# Continuation of Lab 3

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("../Data/japan_life_expectancy.csv")
df.head()
# Out:
#   Prefecture  Life_expectancy  Physician  Junior_col  University  Public_Hosp  \
# 0      Aichi            84.65      224.4        13.6        23.7         13.7
# 1      Akita            83.79      242.6        11.3        11.9         34.0
# 2     Aomori            82.80      212.5        11.4        11.8         42.9
# 3      Chiba            84.48      205.8        14.7        24.9         16.1
# 4      Ehime            84.24      276.7        14.2        18.0         17.4
#
#    Pshic_hosp  Beds_psic  Nurses  Avg_hours  ...  Park  Forest  \
# 0         0.5      164.3   845.4      171.5  ...  17.2    42.1
# 1         1.7      404.6  1105.5      173.0  ...  10.6    70.3
# 2         1.4      348.7  1108.8      174.5  ...  11.8    63.6
# 3         0.5      195.8   749.1      173.5  ...   5.5    30.1
# 4         1.0      329.7  1277.5      178.0  ...   7.2    70.5
#
#    Income_per capita  Density_pop  Hospitals    Beds  Ambulances  Health_exp  \
# ...

# %% [markdown]
# ### Create Correlation table of all columns with Life Expectancy

# %%
correlation_matrix = df.corr()
life_expectancy_corr = correlation_matrix["Life_expectancy"].sort_values(ascending=False)
print(life_expectancy_corr)
# Out:
# Life_expectancy      1.000000
# Junior_col           0.569207
# University           0.560164
# Salary               0.406123
# Park                 0.333984
# Physician            0.321545
# Income_per capita    0.187115
# Density_pop          0.158864
# Educ_exp             0.146163
# Forest               0.092351
# Welfare_exp          0.013767
# Nurses              -0.054996
# Public_Hosp         -0.091038
# Hospitals           -0.092374
# Avg_hours           -0.111068
# Beds                -0.118355
# Sport_fac           -0.130514
# Health_exp          -0.201134
# Pshic_hosp          -0.240471
# Beds_psic           -0.263259
# Ambulances          -0.305427
# Elementary_school   -0.559066
# Name: Life_expectancy, dtype: float64
# ...

# %% [markdown]
# ### Draw Upper and Lower Triagular Heatmap for the dataset

# %%
# Full correlation matrix heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Full Correlation Matrix')
plt.show()

# Create upper triangle mask
upper_triangle = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))

# Upper triangle heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(upper_triangle, annot=True, cmap='coolwarm', fmt='.2f', mask=upper_triangle.isnull())
plt.title('Upper Triangle of Correlation Matrix')
plt.show()

# Create lower triangle mask
lower_triangle = correlation_matrix.where(np.tril(np.ones(correlation_matrix.shape), k=-1).astype(bool))

# Lower triangle heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(lower_triangle, annot=True, cmap='coolwarm', fmt='.2f', mask=lower_triangle.isnull())
plt.title('Lower Triangle of Correlation Matrix')
plt.show()

# %% [markdown]
# ### Draw the 3 Different types of Correlation Matrix

# %%
# Pearson correlation
pearson_corr = df.corr(method='pearson')
plt.figure(figsize=(12, 10))
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Pearson Correlation Matrix')
plt.show()

# Spearman correlation
spearman_corr = df.corr(method='spearman')
plt.figure(figsize=(12, 10))
sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Spearman Correlation Matrix')
plt.show()

# Kendall correlation
kendall_corr = df.corr(method='kendall')
plt.figure(figsize=(12, 10))
sns.heatmap(kendall_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Kendall Correlation Matrix')
plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_26468\3619384890.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pearson_corr = df.corr(method='pearson')
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_26468\3619384890.py:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   spearman_corr = df.corr(method='spearman')
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_26468\3619384890.py:16: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   kendall_corr = df.corr(method='kendall')

# %% [markdown]
# ### Find the Best Correlation Matrix
#
# 1. Pearson Correlation:
#     - You have continuous data that is normally distributed and linearly realted.
#
# 2. Spearman Correlation:
#     - You have ordinal data or non-normally distributed continuous data that might have a monotonic relationship.
#
# 3. Kendall's Tau:
#     - You have ordinal data or when you have a small sample size or data ties (duplicate ranks)
